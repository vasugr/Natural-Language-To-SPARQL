# %%
a = [1]
train_sparql = open("data/lc_quad_sport_art/data_300.sparql",'r')
for l in train_sparql.readlines():
    a.append(l.split("\n")[0])
    
b = [1]
train_en = open("data/lc_quad_sport_art/data_300.en",'r')
for l in train_en.readlines():
    b.append(l.split("\n")[0])

b = b[1:]
a = a[1:]
train = open("data/lc_quad_sport_art/train.txt",'w')
for i in range(len(a)):
    train.write(b[i]+"\t"+a[i]+'\n')

# %%
a
# Out:
# ['SELECT DISTINCT COUNT attr_open var_uri attr_close where brack_open var_x dbo_architect dbr_Skidmore,_Owings_and_Merrill sep_dot var_x dbp_locationTown var_uri sep_dot var_uri a dbo_City brack_close',
#  'SELECT DISTINCT COUNT attr_open var_uri attr_close where brack_open var_x dbo_architect dbr_Horatio_Nelson_Goulty sep_dot var_x dbp_locationTown var_uri sep_dot var_uri a dbo_City brack_close',
#  'SELECT DISTINCT COUNT attr_open var_uri attr_close where brack_open var_uri dbp_creators dbr_Grant_Morrison sep_dot var_uri a dbo_ComicsCharacter brack_close',
#  'SELECT DISTINCT COUNT attr_open var_uri attr_close where brack_open var_uri dbp_creators dbr_Gardner_Fox sep_dot var_uri a dbo_ComicsCharacter brack_close',
#  'SELECT DISTINCT COUNT attr_open var_uri attr_close where brack_open var_uri dbp_creators dbr_Stan_Lee sep_dot var_uri a dbo_ComicsCharacter brack_close',
# ...

# %%
a
# Out:
# ['select var_a where brack_open dbr_European_route_E232 <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_Loughinisland <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_Pan-European_Corridor_II <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_Ringsend,_County_Londonderry <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_European_route_E573 <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_Balloo,_County_Antrim <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_Maydown <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_Aghaginduff <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_European_route_E18 <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_AH48 <dbo_county> var_a brack_close',
#  'select var_a where brack_open dbr_European_route_E88 <dbo_county> var_a brack_close',
# ...

# %%
train = open("data/Compositions2/test.txt",'w')
for i in range(len(a)):
    train.write(b[i]+"\t"+a[i]+'\n')

# %%
a[-1]
# Out:
# 'select var_a where brack_open dbr_Ozark_Mountain_American_Viticultural_Area dbo_subregion var_b sep_dot var_b <dbo_location> var_a brack_close'
